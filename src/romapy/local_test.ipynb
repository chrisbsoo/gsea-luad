# %%
# Out:
# resultROMA(3 modules x 1 samples, 2 significant at l1_pval<0.05)
#     l1  l1_pval  coord
# A  0.6     0.01   0.90
# C  0.5     0.02   0.03
#     l1  l1_pval  coord
# C  0.5     0.02   0.03
#     l1  l1_pval  coord
# C  0.5     0.02   0.03
